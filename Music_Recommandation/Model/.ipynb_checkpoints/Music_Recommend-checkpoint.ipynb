# %%
import numpy as np 
import pandas as pd
import os

# %%
musicVec = np.loadtxt('../Data/MusicVec.txt', delimiter=',')

# %%
musicVec.shape
# Out:
# (1500, 256)

# %%
def chooseSimMus():
    musInputList = [236, 344, 407, 426, 744, 214, 1977, 1675, 1535, 1371]
    n = len(musInputList)
    #n = 5
    topn = 10
    #figure1 = np.zeros((img_height*n, img_weight*topn, 3))
    #figure2 = np.zeros((img_height*n, img_weight*topn, 3))
    zs_ = zs / (zs**2).sum(1, keepdims=True)**0.5
    similar_list = []
    for i , one in zip(range(n), musInputList):
        #one = 0 #测试选择0号
        #one = np.random.choice(len(x_train)) #随机选择一张图的序号
        idxs = ((zs**2).sum(1) + (zs[one]**2).sum() - 2 * np.dot(zs, zs[one])).argsort()[:topn]
        similar = [one, idxs.tolist()]
        similar_list.append(similar)
    return similar_list

def randomSimMus():
    #musInputList = [236, 344, 407, 426, 744, 214, 1977, 1675, 1535, 1371]
    n = 30
    topn = 11
    #figure1 = np.zeros((img_height*n, img_weight*topn, 3))
    #figure2 = np.zeros((img_height*n, img_weight*topn, 3))
    zs_ = zs / (zs**2).sum(1, keepdims=True)**0.5
    similar_list = []
    for i in range(n):
        one = np.random.choice(len(x_train)) #随机选择一张图的序号
        idxs = ((zs**2).sum(1) + (zs[one]**2).sum() - 2 * np.dot(zs, zs[one])).argsort()[:topn]
        similar = [one, idxs.tolist()]
        similar_list.append(similar)
    return similar_list

# %%
similar_list = randomSimMus(musicVec)
similar_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-48469a46bf61> in <module>
# ----> 1 similar_list = randomSimMus(musicVec)
#       2 similar_list
#
# TypeError: randomSimMus() takes 0 positional arguments but 1 was given

# %%
similar_dic = {}
for img_id, name_list in similar_list:
    similar_dic[img_id] = name_list
similar_dic
# Out:
# {16: [16, 1493, 115, 805, 1363, 1103, 1254, 170, 1163, 136, 212],
#  668: [668, 245, 764, 262, 1240, 1171, 302, 93, 536, 1252, 254],
#  911: [911, 1268, 1344, 1017, 343, 6, 751, 85, 1157, 1470, 643],
#  530: [530, 277, 111, 596, 1329, 578, 225, 881, 681, 709, 1172],
#  793: [793, 870, 1356, 194, 400, 1365, 52, 921, 403, 95, 679],
#  3: [3, 228, 1093, 745, 1183, 975, 462, 270, 1064, 1251, 1238],
#  794: [794, 400, 879, 531, 1413, 856, 792, 1197, 1329, 391, 450],
#  778: [778, 1102, 1095, 1054, 263, 1252, 254, 1237, 947, 458, 992],
#  1290: [1290, 277, 578, 870, 856, 530, 743, 225, 1099, 1284, 1102],
#  429: [429, 986, 303, 1364, 1055, 1007, 1240, 1309, 536, 1, 467],
#  885: [885, 420, 1297, 100, 536, 1388, 1294, 1095, 1237, 387, 473],
#  1112: [1112, 373, 638, 512, 486, 1030, 52, 1490, 1309, 825, 42],
#  1109: [1109, 195, 1471, 765, 799, 1373, 583, 1417, 899, 1443, 663],
#  637: [637, 1267, 17, 1027, 320, 1145, 1015, 466, 1432, 1367, 1248],
#  560: [560, 478, 979, 1365, 272, 734, 959, 1015, 1378, 110, 1473],
#  934: [934, 103, 990, 1299, 1111, 1121, 1135, 907, 8, 451, 36],
#  1398: [1398, 886, 274, 133, 1134, 1067, 1096, 35, 462, 1063, 699],
#  340: [340, 666, 1024, 112, 365, 1196, 970, 764, 1004, 737, 1099],
#  11: [11, 26, 1119, 1495, 956, 808, 1496, 921, 1197, 794, 1310],
#  420: [420, 373, 536, 825, 885, 48, 923, 1259, 326, 1103, 866],
#  1182: [1182, 757, 1141, 156, 1312, 1051, 1159, 517, 68, 414, 940],
#  939: [939, 891, 560, 337, 1156, 1187, 1090, 116, 41, 1365, 1175],
#  700: [700, 373, 1490, 272, 48, 1058, 326, 175, 467, 194, 1081],
#  1017: [1017, 1135, 210, 790, 1179, 344, 450, 1268, 932, 85, 941],
#  249: [249, 901, 422, 1055, 1186, 56, 683, 46, 303, 1173, 118],
#  1019: [1019, 142, 1043, 435, 712, 1037, 839, 421, 858, 1237, 1300],
#  667: [667, 1343, 1426, 49, 1324, 498, 577, 450, 518, 808, 921],
#  1326: [1326, 771, 607, 1006, 155, 351, 455, 1158, 994, 37, 1155],
#  724: [724, 468, 109, 20, 990, 1111, 1040, 1121, 678, 985, 1026],
#  578: [578, 225, 1197, 794, 1238, 85, 686, 399, 1121, 1040, 856]}

# %%
similar_arr = pd.DataFrame(similar_dic)

# %%
similar_arr.to_csv('../Data/SimilaryMusicIndex.csv', index=False)
similar_arr
# Out:
#     16    668   911   530   793   3     794   778   1290  429   ...   1182  \
# 0     16   668   911   530   793     3   794   778  1290   429  ...   1182
# 1   1493   245  1268   277   870   228   400  1102   277   986  ...    757
# 2    115   764  1344   111  1356  1093   879  1095   578   303  ...   1141
# 3    805   262  1017   596   194   745   531  1054   870  1364  ...    156
# 4   1363  1240   343  1329   400  1183  1413   263   856  1055  ...   1312
# 5   1103  1171     6   578  1365   975   856  1252   530  1007  ...   1051
# 6   1254   302   751   225    52   462   792   254   743  1240  ...   1159
# 7    170    93    85   881   921   270  1197  1237   225  1309  ...    517
# 8   1163   536  1157   681   403  1064  1329   947  1099   536  ...     68
# 9    136  1252  1470   709    95  1251   391   458  1284     1  ...    414
# 10   212   254   643  1172   679  1238   450   992  1102   467  ...    940
#
#     939   700   1017  249   1019  667   1326  724   578
# 0    939   700  1017   249  1019   667  1326   724   578
# 1    891   373  1135   901   142  1343   771   468   225
# 2    560  1490   210   422  1043  1426   607   109  1197
# 3    337   272   790  1055   435    49  1006    20   794
# 4   1156    48  1179  1186   712  1324   155   990  1238
# 5   1187  1058   344    56  1037   498   351  1111    85
# 6   1090   326   450   683   839   577   455  1040   686
# 7    116   175  1268    46   421   450  1158  1121   399
# 8     41   467   932   303   858   518   994   678  1121
# 9   1365   194    85  1173  1237   808    37   985  1040
# 10  1175  1081   941   118  1300   921  1155  1026   856
#
# [11 rows x 30 columns]

# %%
img_ind_data = pd.read_csv('../Data/SimilaryMusicIndex.csv')
tarImgs = img_ind_data.columns.tolist()
img_data = pd.read_csv('../Data/nameIndex.csv', names=['id', 'name'])
img_data.head()
# Out:
#    id                                       name
# 0   0  Drop Tower - Pluto (Drop Tower Remix).mp3
# 1   1                          iris - Letter.mp3
# 2   2         ZENI - With You (Original Mix).mp3
# 3   3                                 Hey Oh.mp3
# 4   4                        Let Me Love You.mp3

# %%
Music_dic = {}

# %%
for img_id in tarImgs:
    targetImg = img_data[img_data['id']==int(img_id)]
    targetImgName = targetImg['name'].values[0]
    simImgs = img_ind_data[img_id].values.tolist()
    print("Input Image name is:"+'\n', targetImgName)
    print('Similar Image name is:')
    Music_dic[targetImgName] = []
    for sims in simImgs:
        #print(sims)
        simImage = img_data[img_data['id']==int(sims)]
        simName = simImage['name'].values[0]
        Music_dic[targetImgName].append(simName)
        print('\t' + os.path.join('/home/bob/Music/music_dataset', simName))
    print('\n')
# Out:
# Input Image name is:
#  Gill Chang,Aviella - Real Life.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Gill Chang,Aviella - Real Life.mp3
# 	/home/bob/Music/music_dataset/Gill Chang Aviella - Real Life.mp3
# 	/home/bob/Music/music_dataset/D1ofaquavibe - The Party Troll.mp3
# 	/home/bob/Music/music_dataset/Ingrid Michaelson-Everybody.mp3
# 	/home/bob/Music/music_dataset/Gimme That (Remix)_Chris Brown.mp3
# 	/home/bob/Music/music_dataset/Emily Zeck - Two Cents (Ice Cream Song).mp3
# 	/home/bob/Music/music_dataset/Disco Inferno_50 Cent.flac
# 	/home/bob/Music/music_dataset/Swish Swish.mp3
# 	/home/bob/Music/music_dataset/Paradise Fears-Stereo Hearts.mp3
# 	/home/bob/Music/music_dataset/Mayer Hawthorne - Designer Drug.mp3
# 	/home/bob/Music/music_dataset/Deadmau5 - Assorted (Original Mix).flac
#
#
# Input Image name is:
#  한울 - 나예요(Inst.).mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/한울 - 나예요(Inst.).mp3
# 	/home/bob/Music/music_dataset/See You Again.mp3
# 	/home/bob/Music/music_dataset/See You Again_Various Artists.mp3
# 	/home/bob/Music/music_dataset/Lightscape - Cold (Original Mix).mp3
# 	/home/bob/Music/music_dataset/Lainey Lou-Oceanside.mp3
# 	/home/bob/Music/music_dataset/수란 (SURAN)-I Feel (我感觉).m4a
# 	/home/bob/Music/music_dataset/gnash;Olivia O'Brien-i hate u i love u.mp3
# 	/home/bob/Music/music_dataset/i hate u i love u_gnash.mp3
# 	/home/bob/Music/music_dataset/Wonderful U (Demo Version).mp3
# 	/home/bob/Music/music_dataset/Flower Dance.mp3
# 	/home/bob/Music/music_dataset/DJ Okawari - Flower Dance.mp3
#
#
# Input Image name is:
#  I Miss You.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/I Miss You.mp3
# 	/home/bob/Music/music_dataset/Irreplaceable_Beyoncé.flac
# 	/home/bob/Music/music_dataset/Get Ugly_Jason DeRulo.mp3
# 	/home/bob/Music/music_dataset/Lil Wayne,Wiz Khalifa,Imagine Dragons - Sucker For Pain.flac
# 	/home/bob/Music/music_dataset/Vance Joy - Riptide.flac
# 	/home/bob/Music/music_dataset/Aankhen Khuli.mp3
# 	/home/bob/Music/music_dataset/R3hab Quintino - I Just Can't.mp3
# 	/home/bob/Music/music_dataset/Charlie Puth-One Call Away.mp3
# 	/home/bob/Music/music_dataset/Eastblock Bitches - Don't Speak.mp3
# 	/home/bob/Music/music_dataset/Close to You(feat. Jasmine Sok_Lucian.mp3
# 	/home/bob/Music/music_dataset/WEAVER-くちづけDiamond (亲吻Diamond).m4a
#
#
# Input Image name is:
#  Lover Boy 88.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Lover Boy 88.mp3
# 	/home/bob/Music/music_dataset/Extreme (Original Mix)_KSHMR.mp3
# 	/home/bob/Music/music_dataset/Phone Down.mp3
# 	/home/bob/Music/music_dataset/Love The Way You Lie_Eminem.mp3
# 	/home/bob/Music/music_dataset/Can You Feel My World.mp3
# 	/home/bob/Music/music_dataset/Tired.mp3
# 	/home/bob/Music/music_dataset/Tired_Alan Walker.wav
# 	/home/bob/Music/music_dataset/OK.mp3
# 	/home/bob/Music/music_dataset/Special_Six60.mp3
# 	/home/bob/Music/music_dataset/Love the Way You Lie _Eminem.mp3
# 	/home/bob/Music/music_dataset/My Type.mp3
#
#
# Input Image name is:
#  Matisse & Sadko Hanne Mjøen - Into You.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Matisse & Sadko Hanne Mjøen - Into You.mp3
# 	/home/bob/Music/music_dataset/First Time.mp3
# 	/home/bob/Music/music_dataset/Trouble Is A Friend.mp3
# 	/home/bob/Music/music_dataset/It Won't Kill Ya.mp3
# 	/home/bob/Music/music_dataset/Dream It Possible.mp3
# 	/home/bob/Music/music_dataset/Illuminate_The Kite String Tangle.mp3
# 	/home/bob/Music/music_dataset/JULY.mp3
# 	/home/bob/Music/music_dataset/Scream & Shout_will.i.am.flac
# 	/home/bob/Music/music_dataset/Rameses B - A New Start.flac
# 	/home/bob/Music/music_dataset/Lost Kings,Sabrina Carpenter - First Love.mp3
# 	/home/bob/Music/music_dataset/Lean On_Various Artists.mp3
#
#
# Input Image name is:
#  Hey Oh.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Hey Oh.mp3
# 	/home/bob/Music/music_dataset/Nothing In The World.mp3
# 	/home/bob/Music/music_dataset/Joy Williams - Sunny Day.mp3
# 	/home/bob/Music/music_dataset/Wild Child_Brett Dennen.mp3
# 	/home/bob/Music/music_dataset/The Band Perry-If I Die Young.mp3
# 	/home/bob/Music/music_dataset/Sarah Harmer - One Match.mp3
# 	/home/bob/Music/music_dataset/DEVIN K - Rendezvous.flac
# 	/home/bob/Music/music_dataset/Justin Timberlake,Black Eyed Peas - Where Is The Love？.mp3
# 	/home/bob/Music/music_dataset/Echoes of Nature-Awakening of Nature.m4a
# 	/home/bob/Music/music_dataset/Sarah Harmer-One Match.mp3
# 	/home/bob/Music/music_dataset/Taylor Swift - Mine.mp3
#
#
# Input Image name is:
#  G.E.M. 邓紫棋-雨蝶 (Live).m4a
# Similar Image name is:
# 	/home/bob/Music/music_dataset/G.E.M. 邓紫棋-雨蝶 (Live).m4a
# 	/home/bob/Music/music_dataset/Dream It Possible.mp3
# 	/home/bob/Music/music_dataset/Skylar Grey-I Will Return.mp3
# 	/home/bob/Music/music_dataset/Shy Girl_Kedam.mp3
# 	/home/bob/Music/music_dataset/Frida Amundsen-Someone Make Me Cry.mp3
# 	/home/bob/Music/music_dataset/Love the Way You Lie (Part II)_Rihanna.mp3
# 	/home/bob/Music/music_dataset/Niall Horan-This Town.mp3
# 	/home/bob/Music/music_dataset/Mike Perry Tessa - Stay Young.mp3
# 	/home/bob/Music/music_dataset/Can You Feel My World.mp3
# 	/home/bob/Music/music_dataset/Gareth Emery,London Thor,Diviners - Hands (Diviners Remix).mp3
# 	/home/bob/Music/music_dataset/Silence.mp3
#
#
# Input Image name is:
#  เจอกับตัวเองถึงรู้.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/เจอกับตัวเองถึงรู้.mp3
# 	/home/bob/Music/music_dataset/SING女团-不羡.m4a
# 	/home/bob/Music/music_dataset/Schnappi.mp3
# 	/home/bob/Music/music_dataset/DJ Siesta - Another Day.mp3
# 	/home/bob/Music/music_dataset/Because of You.mp3
# 	/home/bob/Music/music_dataset/Flower Dance.mp3
# 	/home/bob/Music/music_dataset/DJ Okawari - Flower Dance.mp3
# 	/home/bob/Music/music_dataset/Sky (Radio Edit).mp3
# 	/home/bob/Music/music_dataset/Twins-莫斯科没有眼泪.m4a
# 	/home/bob/Music/music_dataset/Martin Mittone - Horizon of Time.flac
# 	/home/bob/Music/music_dataset/The truth that you leave.mp3
#
#
# Input Image name is:
#  All My Love.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/All My Love.mp3
# 	/home/bob/Music/music_dataset/Extreme (Original Mix)_KSHMR.mp3
# 	/home/bob/Music/music_dataset/Tired.mp3
# 	/home/bob/Music/music_dataset/First Time.mp3
# 	/home/bob/Music/music_dataset/Love the Way You Lie (Part II)_Rihanna.mp3
# 	/home/bob/Music/music_dataset/Lover Boy 88.mp3
# 	/home/bob/Music/music_dataset/DAISHI DANCE - Re...Japanesque.flac
# 	/home/bob/Music/music_dataset/Tired_Alan Walker.wav
# 	/home/bob/Music/music_dataset/J.Fla (제이플라)-화살 (Arrow) (箭).m4a
# 	/home/bob/Music/music_dataset/Lemon.mp3
# 	/home/bob/Music/music_dataset/SING女团-不羡.m4a
#
#
# Input Image name is:
#  Anan Ryoko - Refrain.flac
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Anan Ryoko - Refrain.flac
# 	/home/bob/Music/music_dataset/karuta-一番の宝物 (最珍贵的宝物) (Original Version).m4a
# 	/home/bob/Music/music_dataset/운명.mp3
# 	/home/bob/Music/music_dataset/Lenka - Don't Let Me Fall.mp3
# 	/home/bob/Music/music_dataset/Philter - Dance Of The Fireflies.mp3
# 	/home/bob/Music/music_dataset/Poison In The Well_Marie Hines.mp3
# 	/home/bob/Music/music_dataset/Lainey Lou-Oceanside.mp3
# 	/home/bob/Music/music_dataset/Josh Vietti - A Thousand Miles.flac
# 	/home/bob/Music/music_dataset/Wonderful U (Demo Version).mp3
# 	/home/bob/Music/music_dataset/iris - Letter.mp3
# 	/home/bob/Music/music_dataset/I'm Yours_Jason Mraz.flac
#
#
# Input Image name is:
#  Colbie Caillat,Jason Mraz - Lucky (Re-Mastered Version).mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Colbie Caillat,Jason Mraz - Lucky (Re-Mastered Version).mp3
# 	/home/bob/Music/music_dataset/Jasmine Sokko-#0000FF (Live).m4a
# 	/home/bob/Music/music_dataset/Holding_Rachel Stevener.mp3
# 	/home/bob/Music/music_dataset/F4-流星雨.m4a
# 	/home/bob/Music/music_dataset/Wonderful U (Demo Version).mp3
# 	/home/bob/Music/music_dataset/Robert de Boron - Chiru (Saisei no Uta).mp3
# 	/home/bob/Music/music_dataset/EGOIST (エゴイスト)-エウテルペ (欧忒耳佩).m4a
# 	/home/bob/Music/music_dataset/Schnappi.mp3
# 	/home/bob/Music/music_dataset/Sky (Radio Edit).mp3
# 	/home/bob/Music/music_dataset/Shape Of You (NOTD Remix)_NOTD.wav
# 	/home/bob/Music/music_dataset/Wish You Were Here_Lady Gaga.mp3
#
#
# Input Image name is:
#  Doar Cu Tine.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Doar Cu Tine.mp3
# 	/home/bob/Music/music_dataset/Jason Mraz - I'm Yours.mp3
# 	/home/bob/Music/music_dataset/Lonely Together.mp3
# 	/home/bob/Music/music_dataset/The Chainsmokers;Phoebe Ryan-All We Know.mp3
# 	/home/bob/Music/music_dataset/Young Hearts (Axero Remix)_Axero.mp3
# 	/home/bob/Music/music_dataset/Light My Body Up.mp3
# 	/home/bob/Music/music_dataset/JULY.mp3
# 	/home/bob/Music/music_dataset/Dark Side_Phoebe Ryan.wav
# 	/home/bob/Music/music_dataset/Josh Vietti - A Thousand Miles.flac
# 	/home/bob/Music/music_dataset/You Are Free - Regrets (Too Late).mp3
# 	/home/bob/Music/music_dataset/Hunter.mp3
#
#
# Input Image name is:
#  Here in Your Bedroom_Goldfinger.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Here in Your Bedroom_Goldfinger.mp3
# 	/home/bob/Music/music_dataset/Does It Offend You, Yeah？ - All The Same.mp3
# 	/home/bob/Music/music_dataset/Shane Filan - Beautiful In White (Demo).mp3
# 	/home/bob/Music/music_dataset/Tell Me.mp3
# 	/home/bob/Music/music_dataset/Hit or Miss_Jacob Sartorius.wav
# 	/home/bob/Music/music_dataset/Where The Hood At_DMX.flac
# 	/home/bob/Music/music_dataset/I Want You to Know_Zedd.mp3
# 	/home/bob/Music/music_dataset/Maroon 5 - Maps.flac
# 	/home/bob/Music/music_dataset/Kiss When the Sun Don't Shine.mp3
# 	/home/bob/Music/music_dataset/Chris Brown - With You.mp3
# 	/home/bob/Music/music_dataset/Firework_Katy Perry.flac
#
#
# Input Image name is:
#  Steven Sharp Nelson - The Cello Song.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Steven Sharp Nelson - The Cello Song.mp3
# 	/home/bob/Music/music_dataset/Omar Akram - Run Away With Me.mp3
# 	/home/bob/Music/music_dataset/2002-Lady of the Moon.m4a
# 	/home/bob/Music/music_dataset/Electus - Nero.mp3
# 	/home/bob/Music/music_dataset/Jo Blankenburg - Villanelle.flac
# 	/home/bob/Music/music_dataset/Look To Me_Azure Ray.mp3
# 	/home/bob/Music/music_dataset/Jason Mraz - The Remedy (I Won't Worry) (LP Version).mp3
# 	/home/bob/Music/music_dataset/Taylor Swift - Crazier.mp3
# 	/home/bob/Music/music_dataset/Five Hundred Miles.mp3
# 	/home/bob/Music/music_dataset/DJ Snake;Justin Bieber-Let Me Love You.mp3
# 	/home/bob/Music/music_dataset/Let Me Love You_DJ Snake.wav
#
#
# Input Image name is:
#  Tino Coury-Circles.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Tino Coury-Circles.mp3
# 	/home/bob/Music/music_dataset/Shawn Mendes-Mercy.mp3
# 	/home/bob/Music/music_dataset/Mariah Carey - I Stay In Love.flac
# 	/home/bob/Music/music_dataset/Illuminate_The Kite String Tangle.mp3
# 	/home/bob/Music/music_dataset/Wake Up Where You Are_State of Sound.mp3
# 	/home/bob/Music/music_dataset/Tyron Hapi,Mimoza - Anyway.mp3
# 	/home/bob/Music/music_dataset/Rigel Theatre - Grad Erlija -Retrospektiva-.mp3
# 	/home/bob/Music/music_dataset/Jason Mraz - The Remedy (I Won't Worry) (LP Version).mp3
# 	/home/bob/Music/music_dataset/Matt Beilis - We've Been Here Before.mp3
# 	/home/bob/Music/music_dataset/Hall of Fame.mp3
# 	/home/bob/Music/music_dataset/Joel Fletcher,Bianca - Smooth Operator.mp3
#
#
# Input Image name is:
#  Lonely.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Lonely.mp3
# 	/home/bob/Music/music_dataset/We Can't Stop (Radio Edit)_Various Artists.mp3
# 	/home/bob/Music/music_dataset/Emoji_Albert Dyrlund.mp3
# 	/home/bob/Music/music_dataset/Guido Negraszus - Across the Mountains.mp3
# 	/home/bob/Music/music_dataset/Hymn For The Weekend (Alan Wal_Alan Walker.mp3
# 	/home/bob/Music/music_dataset/Martin Jensen - All I Wanna Do.mp3
# 	/home/bob/Music/music_dataset/Deadmau5 - Overdraft (Original Mix).flac
# 	/home/bob/Music/music_dataset/Monster_Lady Gaga.ape
# 	/home/bob/Music/music_dataset/Jessie J;B.o.B-Price Tag.mp3
# 	/home/bob/Music/music_dataset/Friends (Rock Mafia & David Jo_Aura Dione.mp3
# 	/home/bob/Music/music_dataset/Higher_Tobu.wav
#
#
# Input Image name is:
#  Floorfiller.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Floorfiller.mp3
# 	/home/bob/Music/music_dataset/Single Ladies (Put A Ring On I_Beyoncé.flac
# 	/home/bob/Music/music_dataset/Rockabye.mp3
# 	/home/bob/Music/music_dataset/Take It Off_Kesha.flac
# 	/home/bob/Music/music_dataset/Hampton the Hampster - The Hampster Dance Song.mp3
# 	/home/bob/Music/music_dataset/The Hampster Dance Song.mp3
# 	/home/bob/Music/music_dataset/Zara Larsson-Uncover.mp3
# 	/home/bob/Music/music_dataset/Klingande - Pumped Up.mp3
# 	/home/bob/Music/music_dataset/DEVIN K - Rendezvous.flac
# 	/home/bob/Music/music_dataset/The Sweet Escape_Gwen Stefani.flac
# 	/home/bob/Music/music_dataset/LoveGame_Lady Gaga.flac
#
#
# Input Image name is:
#  Ngẫu Hứng_Hoaprox.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Ngẫu Hứng_Hoaprox.mp3
# 	/home/bob/Music/music_dataset/Hoaprox - Ngẫu Hứng.mp3
# 	/home/bob/Music/music_dataset/Sleep Dealer - Hidden Path.mp3
# 	/home/bob/Music/music_dataset/Anima - You Are Truth.mp3
# 	/home/bob/Music/music_dataset/Senpai,Kondor - Tomorrow With You.mp3
# 	/home/bob/Music/music_dataset/jinsang - summer's day [version 2].mp3
# 	/home/bob/Music/music_dataset/Kanic - Lux Aestiva.mp3
# 	/home/bob/Music/music_dataset/See You Again_Various Artists.mp3
# 	/home/bob/Music/music_dataset/Telephone.mp3
# 	/home/bob/Music/music_dataset/July - Somewhere.mp3
# 	/home/bob/Music/music_dataset/J.Fla (제이플라)-화살 (Arrow) (箭).m4a
#
#
# Input Image name is:
#  Diamonds_Rihanna.flac
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Diamonds_Rihanna.flac
# 	/home/bob/Music/music_dataset/Tyron Hapi,Mashd N Kutcher - We Could Be.mp3
# 	/home/bob/Music/music_dataset/Leona Lewis - Better in Time (Single Mix).mp3
# 	/home/bob/Music/music_dataset/GALA-追梦赤子心.m4a
# 	/home/bob/Music/music_dataset/Set Fire to the Rain_Adele.flac
# 	/home/bob/Music/music_dataset/By Your Side.mp3
# 	/home/bob/Music/music_dataset/Take My Breath Away.mp3
# 	/home/bob/Music/music_dataset/Scream & Shout_will.i.am.flac
# 	/home/bob/Music/music_dataset/Mike Perry Tessa - Stay Young.mp3
# 	/home/bob/Music/music_dataset/G.E.M. 邓紫棋-雨蝶 (Live).m4a
# 	/home/bob/Music/music_dataset/Michael Learns To Rock - Call On Love.mp3
#
#
# Input Image name is:
#  Jasmine Sokko-#0000FF (Live).m4a
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Jasmine Sokko-#0000FF (Live).m4a
# 	/home/bob/Music/music_dataset/Jason Mraz - I'm Yours.mp3
# 	/home/bob/Music/music_dataset/Wonderful U (Demo Version).mp3
# 	/home/bob/Music/music_dataset/You Are Free - Regrets (Too Late).mp3
# 	/home/bob/Music/music_dataset/Colbie Caillat,Jason Mraz - Lucky (Re-Mastered Version).mp3
# 	/home/bob/Music/music_dataset/Phoebe Ryan - Dark Side.mp3
# 	/home/bob/Music/music_dataset/I'm An Albatraoz_Various Artists.mp3
# 	/home/bob/Music/music_dataset/Carly Rae Jepsen - Call Me Maybe.mp3
# 	/home/bob/Music/music_dataset/Chelsea Cutler,Sondr - Wake Up (Sondr Remix).mp3
# 	/home/bob/Music/music_dataset/Emily Zeck - Two Cents (Ice Cream Song).mp3
# 	/home/bob/Music/music_dataset/Troye Sivan - Gasoline.mp3
#
#
# Input Image name is:
#  GRANRODEO (グランロデオ)-Punky Funky Love (TV Version).m4a
# Similar Image name is:
# 	/home/bob/Music/music_dataset/GRANRODEO (グランロデオ)-Punky Funky Love (TV Version).m4a
# 	/home/bob/Music/music_dataset/Kelly Clarkson - Already Gone.mp3
# 	/home/bob/Music/music_dataset/gravityWall_澤野弘之.mp3
# 	/home/bob/Music/music_dataset/Taylor Swift - Last Christmas.mp3
# 	/home/bob/Music/music_dataset/SawanoHiroyuki[nZk] (泽野弘之)-gravityWall.m4a
# 	/home/bob/Music/music_dataset/Fallin'_Poema.mp3
# 	/home/bob/Music/music_dataset/Space - Just Blue.mp3
# 	/home/bob/Music/music_dataset/Walking In the Sun (Defrix Remix).mp3
# 	/home/bob/Music/music_dataset/XX:me-トリカゴ (鸟笼).m4a
# 	/home/bob/Music/music_dataset/TrySail-adrenaline!!!.m4a
# 	/home/bob/Music/music_dataset/순정.mp3
#
#
# Input Image name is:
#  Actium - I Need You.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Actium - I Need You.mp3
# 	/home/bob/Music/music_dataset/Adam Young - Southampton.mp3
# 	/home/bob/Music/music_dataset/Tino Coury-Circles.mp3
# 	/home/bob/Music/music_dataset/Dexter Britain - Summit.mp3
# 	/home/bob/Music/music_dataset/Rameses B - Earth Calls.flac
# 	/home/bob/Music/music_dataset/Electus - Temple of Light.mp3
# 	/home/bob/Music/music_dataset/Trip_Axero.mp3
# 	/home/bob/Music/music_dataset/Rameses B - Spirit Walk.flac
# 	/home/bob/Music/music_dataset/Star Sky - Instrumental.mp3
# 	/home/bob/Music/music_dataset/Illuminate_The Kite String Tangle.mp3
# 	/home/bob/Music/music_dataset/Electus - Peace Of Mind.mp3
#
#
# Input Image name is:
#  Melody.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Melody.mp3
# 	/home/bob/Music/music_dataset/Jason Mraz - I'm Yours.mp3
# 	/home/bob/Music/music_dataset/Dark Side_Phoebe Ryan.wav
# 	/home/bob/Music/music_dataset/Wake Up Where You Are_State of Sound.mp3
# 	/home/bob/Music/music_dataset/Phoebe Ryan - Dark Side.mp3
# 	/home/bob/Music/music_dataset/Ryan Farish - Time Between Us.mp3
# 	/home/bob/Music/music_dataset/Chelsea Cutler,Sondr - Wake Up (Sondr Remix).mp3
# 	/home/bob/Music/music_dataset/Holly Throsby-We Are Good People But Why Don't We Show It.mp3
# 	/home/bob/Music/music_dataset/I'm Yours_Jason Mraz.flac
# 	/home/bob/Music/music_dataset/It Won't Kill Ya.mp3
# 	/home/bob/Music/music_dataset/PRXZM - Forever Young (PRXZM Cover).mp3
#
#
# Input Image name is:
#  Lil Wayne,Wiz Khalifa,Imagine Dragons - Sucker For Pain.flac
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Lil Wayne,Wiz Khalifa,Imagine Dragons - Sucker For Pain.flac
# 	/home/bob/Music/music_dataset/Deadmau5 - Overdraft (Original Mix).flac
# 	/home/bob/Music/music_dataset/Setting Fires.mp3
# 	/home/bob/Music/music_dataset/Rameses B - Once Upon A Time.mp3
# 	/home/bob/Music/music_dataset/G-Eazy,Charlie Puth - Sober.mp3
# 	/home/bob/Music/music_dataset/I Am You.mp3
# 	/home/bob/Music/music_dataset/Silence.mp3
# 	/home/bob/Music/music_dataset/Irreplaceable_Beyoncé.flac
# 	/home/bob/Music/music_dataset/Wisp X - Luv Letter (Wisp X Remix).mp3
# 	/home/bob/Music/music_dataset/Charlie Puth-One Call Away.mp3
# 	/home/bob/Music/music_dataset/Panda_Desiigner.mp3
#
#
# Input Image name is:
#  Ken Arai - BLISS.flac
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Ken Arai - BLISS.flac
# 	/home/bob/Music/music_dataset/Sorrow.mp3
# 	/home/bob/Music/music_dataset/Luigi Rubino - Before Love.mp3
# 	/home/bob/Music/music_dataset/Philter - Dance Of The Fireflies.mp3
# 	/home/bob/Music/music_dataset/Selena Gomez,Marshmello - Wolves.flac
# 	/home/bob/Music/music_dataset/Wolves_Selena Gomez.wav
# 	/home/bob/Music/music_dataset/You.mp3
# 	/home/bob/Music/music_dataset/P!nk;Nate Ruess-Just Give Me a Reason.mp3
# 	/home/bob/Music/music_dataset/운명.mp3
# 	/home/bob/Music/music_dataset/Gerald Peregrine - Black Orpheus.mp3
# 	/home/bob/Music/music_dataset/Martin Mittone - Lunara.flac
#
#
# Input Image name is:
#  See-Saw-君は僕に似ている (你与我相似).m4a
# Similar Image name is:
# 	/home/bob/Music/music_dataset/See-Saw-君は僕に似ている (你与我相似).m4a
# 	/home/bob/Music/music_dataset/MYTH & ROID-STYX HELIX.m4a
# 	/home/bob/Music/music_dataset/Just Hold On.mp3
# 	/home/bob/Music/music_dataset/CZT-绝地重生.m4a
# 	/home/bob/Music/music_dataset/Kjartan Salvesen-Then Silence.mp3
# 	/home/bob/Music/music_dataset/Lenka-Trouble Is a Friend.mp3
# 	/home/bob/Music/music_dataset/Wrong_Far Out.mp3
# 	/home/bob/Music/music_dataset/Nega music project - There, where spring.mp3
# 	/home/bob/Music/music_dataset/ワカバ (Wakaba)-明日、僕は君に会いに行く。 (明天，我要去见你。).m4a
# 	/home/bob/Music/music_dataset/Sky (Radio Edit).mp3
# 	/home/bob/Music/music_dataset/Moonlight Shadow.mp3
#
#
# Input Image name is:
#  High Maintenance_Miranda Cosgrove.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/High Maintenance_Miranda Cosgrove.mp3
# 	/home/bob/Music/music_dataset/Christina Perri - A Thousand Years.mp3
# 	/home/bob/Music/music_dataset/Through My Father's Eyes_Holly Starr.mp3
# 	/home/bob/Music/music_dataset/Infinity_Ahxello.mp3
# 	/home/bob/Music/music_dataset/Triarchy,The Chainsmokers,Jhene Aiko - Wake Up Alone (Triarchy Remix).mp3
# 	/home/bob/Music/music_dataset/Overwerk - Daybreak (GoPro HERO3 Edit).mp3
# 	/home/bob/Music/music_dataset/Daybreak (GoPro HERO3 Edit)_Overwerk.mp3
# 	/home/bob/Music/music_dataset/Silence.mp3
# 	/home/bob/Music/music_dataset/Taylor Swift - The Best Day.mp3
# 	/home/bob/Music/music_dataset/By Your Side.mp3
# 	/home/bob/Music/music_dataset/Scream & Shout_will.i.am.flac
#
#
# Input Image name is:
#  Taylor Swift - Blank Space.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Taylor Swift - Blank Space.mp3
# 	/home/bob/Music/music_dataset/We Are Never Ever Getting Back_Taylor Swift.wav
# 	/home/bob/Music/music_dataset/Moves Like Jagger (Remix)_Maroon 5.mp3
# 	/home/bob/Music/music_dataset/Okey Dokey_Show Me The Money.mp3
# 	/home/bob/Music/music_dataset/Moving On.mp3
# 	/home/bob/Music/music_dataset/Es rappelt im Karton.mp3
# 	/home/bob/Music/music_dataset/Convex Kaizen Shinigami Kass - Bloom (CONVEX Remix).mp3
# 	/home/bob/Music/music_dataset/Convex,Kaizen,Shinigami - Bloom (CONVEX Remix).mp3
# 	/home/bob/Music/music_dataset/7!! (Seven Oops)-オレンジ (Orange).m4a
# 	/home/bob/Music/music_dataset/The Pussycat Dolls - I Hate This Part.flac
# 	/home/bob/Music/music_dataset/This Girl (Kungs Vs Cookin' On 3 Burners).mp3
#
#
# Input Image name is:
#  Fade.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Fade.mp3
# 	/home/bob/Music/music_dataset/Counting Stars.mp3
# 	/home/bob/Music/music_dataset/OneRepublic - Counting Stars.flac
# 	/home/bob/Music/music_dataset/OneRepublic-Counting Stars.mp3
# 	/home/bob/Music/music_dataset/Emoji_Albert Dyrlund.mp3
# 	/home/bob/Music/music_dataset/Hymn For The Weekend (Alan Wal_Alan Walker.mp3
# 	/home/bob/Music/music_dataset/Take me hand.mp3
# 	/home/bob/Music/music_dataset/Martin Jensen - All I Wanna Do.mp3
# 	/home/bob/Music/music_dataset/Tobu - Higher.mp3
# 	/home/bob/Music/music_dataset/Boys Like Girls - Two Is Better Than One (Album Version).mp3
# 	/home/bob/Music/music_dataset/Stive Morgan - Witch Dance.mp3
#
#
# Input Image name is:
#  Tired.mp3
# Similar Image name is:
# 	/home/bob/Music/music_dataset/Tired.mp3
# 	/home/bob/Music/music_dataset/Tired_Alan Walker.wav
# 	/home/bob/Music/music_dataset/Mike Perry Tessa - Stay Young.mp3
# 	/home/bob/Music/music_dataset/G.E.M. 邓紫棋-雨蝶 (Live).m4a
# 	/home/bob/Music/music_dataset/Taylor Swift - Mine.mp3
# 	/home/bob/Music/music_dataset/Charlie Puth-One Call Away.mp3
# 	/home/bob/Music/music_dataset/My Way.mp3
# 	/home/bob/Music/music_dataset/Kate Havnevik-SoLo.mp3
# 	/home/bob/Music/music_dataset/Martin Jensen - All I Wanna Do.mp3
# 	/home/bob/Music/music_dataset/Take me hand.mp3
# 	/home/bob/Music/music_dataset/Love the Way You Lie (Part II)_Rihanna.mp3

# %%
for name in Music_dic.values():
    print(name)
# Out:
# ['Gill Chang,Aviella - Real Life.mp3', 'Gill Chang Aviella - Real Life.mp3', 'D1ofaquavibe - The Party Troll.mp3', 'Ingrid Michaelson-Everybody.mp3', 'Gimme That (Remix)_Chris Brown.mp3', 'Emily Zeck - Two Cents (Ice Cream Song).mp3', 'Disco Inferno_50 Cent.flac', 'Swish Swish.mp3', 'Paradise Fears-Stereo Hearts.mp3', 'Mayer Hawthorne - Designer Drug.mp3', 'Deadmau5 - Assorted (Original Mix).flac']
# ['한울 - 나예요(Inst.).mp3', 'See You Again.mp3', 'See You Again_Various Artists.mp3', 'Lightscape - Cold (Original Mix).mp3', 'Lainey Lou-Oceanside.mp3', '수란 (SURAN)-I Feel (我感觉).m4a', "gnash;Olivia O'Brien-i hate u i love u.mp3", 'i hate u i love u_gnash.mp3', 'Wonderful U (Demo Version).mp3', 'Flower Dance.mp3', 'DJ Okawari - Flower Dance.mp3']
# ['I Miss You.mp3', 'Irreplaceable_Beyoncé.flac', 'Get Ugly_Jason DeRulo.mp3', 'Lil Wayne,Wiz Khalifa,Imagine Dragons - Sucker For Pain.flac', 'Vance Joy - Riptide.flac', 'Aankhen Khuli.mp3', "R3hab Quintino - I Just Can't.mp3", 'Charlie Puth-One Call Away.mp3', "Eastblock Bitches - Don't Speak.mp3", 'Close to You(feat. Jasmine Sok_Lucian.mp3', 'WEAVER-くちづけDiamond (亲吻Diamond).m4a']
# ['Lover Boy 88.mp3', 'Extreme (Original Mix)_KSHMR.mp3', 'Phone Down.mp3', 'Love The Way You Lie_Eminem.mp3', 'Can You Feel My World.mp3', 'Tired.mp3', 'Tired_Alan Walker.wav', 'OK.mp3', 'Special_Six60.mp3', 'Love the Way You Lie _Eminem.mp3', 'My Type.mp3']
# ['Matisse & Sadko Hanne Mjøen - Into You.mp3', 'First Time.mp3', 'Trouble Is A Friend.mp3', "It Won't Kill Ya.mp3", 'Dream It Possible.mp3', 'Illuminate_The Kite String Tangle.mp3', 'JULY.mp3', 'Scream & Shout_will.i.am.flac', 'Rameses B - A New Start.flac', 'Lost Kings,Sabrina Carpenter - First Love.mp3', 'Lean On_Various Artists.mp3']
# ['Hey Oh.mp3', 'Nothing In The World.mp3', 'Joy Williams - Sunny Day.mp3', 'Wild Child_Brett Dennen.mp3', 'The Band Perry-If I Die Young.mp3', 'Sarah Harmer - One Match.mp3', 'DEVIN K - Rendezvous.flac', 'Justin Timberlake,Black Eyed Peas - Where Is The Love？.mp3', 'Echoes of Nature-Awakening of Nature.m4a', 'Sarah Harmer-One Match.mp3', 'Taylor Swift - Mine.mp3']
# ['G.E.M. 邓紫棋-雨蝶 (Live).m4a', 'Dream It Possible.mp3', 'Skylar Grey-I Will Return.mp3', 'Shy Girl_Kedam.mp3', 'Frida Amundsen-Someone Make Me Cry.mp3', 'Love the Way You Lie (Part II)_Rihanna.mp3', 'Niall Horan-This Town.mp3', 'Mike Perry Tessa - Stay Young.mp3', 'Can You Feel My World.mp3', 'Gareth Emery,London Thor,Diviners - Hands (Diviners Remix).mp3', 'Silence.mp3']
# ['เจอกับตัวเองถึงรู้.mp3', 'SING女团-不羡.m4a', 'Schnappi.mp3', 'DJ Siesta - Another Day.mp3', 'Because of You.mp3', 'Flower Dance.mp3', 'DJ Okawari - Flower Dance.mp3', 'Sky (Radio Edit).mp3', 'Twins-莫斯科没有眼泪.m4a', 'Martin Mittone - Horizon of Time.flac', 'The\xa0truth\xa0that\xa0you\xa0leave.mp3']
# ['All My Love.mp3', 'Extreme (Original Mix)_KSHMR.mp3', 'Tired.mp3', 'First Time.mp3', 'Love the Way You Lie (Part II)_Rihanna.mp3', 'Lover Boy 88.mp3', 'DAISHI DANCE - Re...Japanesque.flac', 'Tired_Alan Walker.wav', 'J.Fla (제이플라)-화살 (Arrow) (箭).m4a', 'Lemon.mp3', 'SING女团-不羡.m4a']
# ['Anan Ryoko - Refrain.flac', 'karuta-一番の宝物 (最珍贵的宝物) (Original Version).m4a', '운명.mp3', "Lenka - Don't Let Me Fall.mp3", 'Philter - Dance Of The Fireflies.mp3', 'Poison In The Well_Marie Hines.mp3', 'Lainey Lou-Oceanside.mp3', 'Josh Vietti - A Thousand Miles.flac', 'Wonderful U (Demo Version).mp3', 'iris - Letter.mp3', "I'm Yours_Jason Mraz.flac"]
# ['Colbie Caillat,Jason Mraz - Lucky (Re-Mastered Version).mp3', 'Jasmine Sokko-#0000FF (Live).m4a', 'Holding_Rachel Stevener.mp3', 'F4-流星雨.m4a', 'Wonderful U (Demo Version).mp3', 'Robert de Boron - Chiru (Saisei no Uta).mp3', 'EGOIST (エゴイスト)-エウテルペ (欧忒耳佩).m4a', 'Schnappi.mp3', 'Sky (Radio Edit).mp3', 'Shape Of You (NOTD Remix)_NOTD.wav', 'Wish You Were Here_Lady Gaga.mp3']
# ['Doar Cu Tine.mp3', "Jason Mraz - I'm Yours.mp3", 'Lonely Together.mp3', 'The Chainsmokers;Phoebe Ryan-All We Know.mp3', 'Young Hearts (Axero Remix)_Axero.mp3', 'Light My Body Up.mp3', 'JULY.mp3', 'Dark Side_Phoebe Ryan.wav', 'Josh Vietti - A Thousand Miles.flac', 'You Are Free - Regrets (Too Late).mp3', 'Hunter.mp3']
# ['Here in Your Bedroom_Goldfinger.mp3', 'Does It Offend You, Yeah？ - All The Same.mp3', 'Shane Filan - Beautiful In White (Demo).mp3', 'Tell Me.mp3', 'Hit or Miss_Jacob Sartorius.wav', 'Where The Hood At_DMX.flac', 'I Want You to Know_Zedd.mp3', 'Maroon 5 - Maps.flac', "Kiss When the Sun Don't Shine.mp3", 'Chris Brown - With You.mp3', 'Firework_Katy Perry.flac']
# ['Steven Sharp Nelson - The Cello Song.mp3', 'Omar Akram - Run Away With Me.mp3', '2002-Lady of the Moon.m4a', 'Electus - Nero.mp3', 'Jo Blankenburg - Villanelle.flac', 'Look To Me_Azure Ray.mp3', "Jason Mraz - The Remedy (I Won't Worry) (LP Version).mp3", 'Taylor Swift - Crazier.mp3', 'Five Hundred Miles.mp3', 'DJ Snake;Justin Bieber-Let Me Love You.mp3', 'Let Me Love You_DJ Snake.wav']
# ['Tino Coury-Circles.mp3', 'Shawn Mendes-Mercy.mp3', 'Mariah Carey - I Stay In Love.flac', 'Illuminate_The Kite String Tangle.mp3', 'Wake Up Where You Are_State of Sound.mp3', 'Tyron Hapi,Mimoza - Anyway.mp3', 'Rigel Theatre - Grad Erlija -Retrospektiva-.mp3', "Jason Mraz - The Remedy (I Won't Worry) (LP Version).mp3", "Matt Beilis - We've Been Here Before.mp3", 'Hall of Fame.mp3', 'Joel Fletcher,Bianca - Smooth Operator.mp3']
# ['Lonely.mp3', "We Can't Stop (Radio Edit)_Various Artists.mp3", 'Emoji_Albert Dyrlund.mp3', 'Guido Negraszus - Across the Mountains.mp3', 'Hymn For The Weekend (Alan Wal_Alan Walker.mp3', 'Martin Jensen - All I Wanna Do.mp3', 'Deadmau5 - Overdraft (Original Mix).flac', 'Monster_Lady Gaga.ape', 'Jessie J;B.o.B-Price Tag.mp3', 'Friends (Rock Mafia & David Jo_Aura Dione.mp3', 'Higher_Tobu.wav']
# ['Floorfiller.mp3', 'Single Ladies (Put A Ring On I_Beyoncé.flac', 'Rockabye.mp3', 'Take It Off_Kesha.flac', 'Hampton the Hampster - The Hampster Dance Song.mp3', 'The Hampster Dance Song.mp3', 'Zara Larsson-Uncover.mp3', 'Klingande - Pumped Up.mp3', 'DEVIN K - Rendezvous.flac', 'The Sweet Escape_Gwen Stefani.flac', 'LoveGame_Lady Gaga.flac']
# ['Ngẫu Hứng_Hoaprox.mp3', 'Hoaprox - Ngẫu Hứng.mp3', 'Sleep Dealer - Hidden\xa0Path.mp3', 'Anima - You Are Truth.mp3', 'Senpai,Kondor - Tomorrow With You.mp3', "jinsang - summer's day [version 2].mp3", 'Kanic - Lux Aestiva.mp3', 'See You Again_Various Artists.mp3', 'Telephone.mp3', 'July - Somewhere.mp3', 'J.Fla (제이플라)-화살 (Arrow) (箭).m4a']
# ['Diamonds_Rihanna.flac', 'Tyron Hapi,Mashd N Kutcher - We Could Be.mp3', 'Leona Lewis - Better in Time (Single Mix).mp3', 'GALA-追梦赤子心.m4a', 'Set Fire to the Rain_Adele.flac', 'By Your Side.mp3', 'Take My Breath Away.mp3', 'Scream & Shout_will.i.am.flac', 'Mike Perry Tessa - Stay Young.mp3', 'G.E.M. 邓紫棋-雨蝶 (Live).m4a', 'Michael Learns To Rock - Call On Love.mp3']
# ['Jasmine Sokko-#0000FF (Live).m4a', "Jason Mraz - I'm Yours.mp3", 'Wonderful U (Demo Version).mp3', 'You Are Free - Regrets (Too Late).mp3', 'Colbie Caillat,Jason Mraz - Lucky (Re-Mastered Version).mp3', 'Phoebe Ryan - Dark Side.mp3', "I'm An Albatraoz_Various Artists.mp3", 'Carly Rae Jepsen - Call Me Maybe.mp3', 'Chelsea Cutler,Sondr - Wake Up (Sondr Remix).mp3', 'Emily Zeck - Two Cents (Ice Cream Song).mp3', 'Troye Sivan - Gasoline.mp3']
# ['GRANRODEO (グランロデオ)-Punky Funky Love (TV Version).m4a', 'Kelly Clarkson - Already Gone.mp3', 'gravityWall_澤野弘之.mp3', 'Taylor Swift - Last Christmas.mp3', 'SawanoHiroyuki[nZk] (泽野弘之)-gravityWall.m4a', "Fallin'_Poema.mp3", 'Space - Just Blue.mp3', 'Walking In the Sun (Defrix Remix).mp3', 'XX:me-トリカゴ (鸟笼).m4a', 'TrySail-adrenaline!!!.m4a', '순정.mp3']
# ['Actium - I Need You.mp3', 'Adam Young - Southampton.mp3', 'Tino Coury-Circles.mp3', 'Dexter Britain - Summit.mp3', 'Rameses B - Earth Calls.flac', 'Electus - Temple of Light.mp3', 'Trip_Axero.mp3', 'Rameses B - Spirit Walk.flac', 'Star Sky - Instrumental.mp3', 'Illuminate_The Kite String Tangle.mp3', 'Electus - Peace Of Mind.mp3']
# ['Melody.mp3', "Jason Mraz - I'm Yours.mp3", 'Dark Side_Phoebe Ryan.wav', 'Wake Up Where You Are_State of Sound.mp3', 'Phoebe Ryan - Dark Side.mp3', 'Ryan Farish - Time Between Us.mp3', 'Chelsea Cutler,Sondr - Wake Up (Sondr Remix).mp3', "Holly Throsby-We Are Good People But Why Don't We Show It.mp3", "I'm Yours_Jason Mraz.flac", "It Won't Kill Ya.mp3", 'PRXZM - Forever Young (PRXZM Cover).mp3']
# ['Lil Wayne,Wiz Khalifa,Imagine Dragons - Sucker For Pain.flac', 'Deadmau5 - Overdraft (Original Mix).flac', 'Setting Fires.mp3', 'Rameses B - Once Upon A Time.mp3', 'G-Eazy,Charlie Puth - Sober.mp3', 'I Am You.mp3', 'Silence.mp3', 'Irreplaceable_Beyoncé.flac', 'Wisp\xa0X - Luv Letter (Wisp X Remix).mp3', 'Charlie Puth-One Call Away.mp3', 'Panda_Desiigner.mp3']
# ['Ken Arai - BLISS.flac', 'Sorrow.mp3', 'Luigi Rubino - Before Love.mp3', 'Philter - Dance Of The Fireflies.mp3', 'Selena Gomez,Marshmello - Wolves.flac', 'Wolves_Selena Gomez.wav', 'You.mp3', 'P!nk;Nate Ruess-Just Give Me a Reason.mp3', '운명.mp3', 'Gerald Peregrine - Black Orpheus.mp3', 'Martin Mittone - Lunara.flac']
# ['See-Saw-君は僕に似ている (你与我相似).m4a', 'MYTH & ROID-STYX HELIX.m4a', 'Just Hold On.mp3', 'CZT-绝地重生.m4a', 'Kjartan Salvesen-Then Silence.mp3', 'Lenka-Trouble Is a Friend.mp3', 'Wrong_Far Out.mp3', 'Nega music project - There, where spring.mp3', 'ワカバ (Wakaba)-明日、僕は君に会いに行く。 (明天，我要去见你。).m4a', 'Sky (Radio Edit).mp3', 'Moonlight Shadow.mp3']
# ['High Maintenance_Miranda Cosgrove.mp3', 'Christina Perri - A Thousand Years.mp3', "Through My Father's Eyes_Holly Starr.mp3", 'Infinity_Ahxello.mp3', 'Triarchy,The Chainsmokers,Jhene Aiko - Wake Up Alone (Triarchy Remix).mp3', 'Overwerk - Daybreak (GoPro HERO3 Edit).mp3', 'Daybreak (GoPro HERO3 Edit)_Overwerk.mp3', 'Silence.mp3', 'Taylor Swift - The Best Day.mp3', 'By Your Side.mp3', 'Scream & Shout_will.i.am.flac']
# ['Taylor Swift - Blank Space.mp3', 'We Are Never Ever Getting Back_Taylor Swift.wav', 'Moves Like Jagger (Remix)_Maroon 5.mp3', 'Okey Dokey_Show Me The Money.mp3', 'Moving On.mp3', 'Es rappelt im Karton.mp3', 'Convex Kaizen Shinigami Kass - Bloom (CONVEX Remix).mp3', 'Convex,Kaizen,Shinigami - Bloom (CONVEX Remix).mp3', '7!! (Seven Oops)-オレンジ (Orange).m4a', 'The Pussycat Dolls - I Hate This Part.flac', "This Girl (Kungs Vs Cookin' On 3 Burners).mp3"]
# ['Fade.mp3', 'Counting Stars.mp3', 'OneRepublic - Counting Stars.flac', 'OneRepublic-Counting Stars.mp3', 'Emoji_Albert Dyrlund.mp3', 'Hymn For The Weekend (Alan Wal_Alan Walker.mp3', 'Take me hand.mp3', 'Martin Jensen - All I Wanna Do.mp3', 'Tobu - Higher.mp3', 'Boys Like Girls - Two Is Better Than One (Album Version).mp3', 'Stive Morgan - Witch Dance.mp3']
# ['Tired.mp3', 'Tired_Alan Walker.wav', 'Mike Perry Tessa - Stay Young.mp3', 'G.E.M. 邓紫棋-雨蝶 (Live).m4a', 'Taylor Swift - Mine.mp3', 'Charlie Puth-One Call Away.mp3', 'My Way.mp3', 'Kate Havnevik-SoLo.mp3', 'Martin Jensen - All I Wanna Do.mp3', 'Take me hand.mp3', 'Love the Way You Lie (Part II)_Rihanna.mp3']

# %% [markdown]
# # ---------------------------------------------------------------------

# %%
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

# %%
X_embedded = TSNE(n_components=3, init='pca').fit_transform(musicVec)

# %%
X = TSNE(n_components=2).fit_transform(musicVec)

# %%
X_embedded.shape
# Out:
# (1500, 2)

# %%
X.shape
# Out:
# (1500, 2)

# %%
x_min, x_max = X.min(0), X.max(0)
X_norm = (X - x_min) / (X - x_min)  # 归一化
# Out:
# /home/bob/.conda/envs/pythonDL/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
from sklearn import (manifold, datasets, decomposition, ensemble,random_projection)
import time

# %%
def plot_embedding_2d(X, title=None):
    #坐标缩放到[0,1]区间
    x_min, x_max = np.min(X,axis=0), np.max(X,axis=0)
    X = (X - x_min) / (x_max - x_min)

    #降维后的坐标为（X[i, 0], X[i, 1]），在该位置画出对应的digits
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    for i in range(X.shape[0]):
        ax.text(X[i, 0], X[i, 1],'.',
                 color=plt.cm.Set1(1 / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    if title is not None:
        plt.title(title)

#%%
#将降维后的数据可视化,3维
def plot_embedding_3d(X, title=None):
    #坐标缩放到[0,1]区间
    x_min, x_max = np.min(X,axis=0), np.max(X,axis=0)
    X = (X - x_min) / (x_max - x_min)

    #降维后的坐标为（X[i, 0], X[i, 1],X[i,2]），在该位置画出对应的digits
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1, projection='3d')
    for i in range(X.shape[0]):
        ax.text(X[i, 0], X[i, 1], X[i,2],'.',
                 color=plt.cm.Set1(1 / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    if title is not None:
        plt.title(title)

# %%
plot_embedding_2d(X)
plot_embedding_3d(X_embedded)

# %%
#PCA
print("Computing PCA projection")
t0 = time()
X_pca = decomposition.TruncatedSVD(n_components=3).fit_transform(musicVec)
plot_embedding_2d(X_pca[:,0:2],"PCA 2D")
plot_embedding_3d(X_pca,"PCA 3D (time %.2fs)" %(time() - t0))
# Out:
# Computing PCA projection

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

n_clusters = 10
clf = KMeans(n_clusters, n_init=20)
clf.fit(X_embedded)
cents = clf.cluster_centers_
labels = clf.labels_
#sse = clf.s
#画出聚类结果，每一类用一种颜色
colors = ['b','g','r','k','c','m','y','#e24fff','#524C90','#845868',
         'b','g','r','k','c','m','y','#e24fff','#524C90','#845868']
for i in range(n_clusters):
    index = np.nonzero(labels==i)[0]
    x0 = X[index,0]
    x1 = X[index,1]
    y_i = labels[index]
    for j in range(len(x0)):
        plt.text(x0[j],x1[j],str(int(y_i[j])),color=colors[i],\
                fontdict={'weight': 'bold', 'size': 9})
    plt.scatter(cents[i,0],cents[i,1],marker='x',color=colors[i],linewidths=12)
#plt.title("SSE={:.2f}".format(sse))
plt.axis([-30,30,-30,30])
plt.show()
